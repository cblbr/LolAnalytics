# %% [markdown]
# **Goal of this notebook is to expand the high_diamond_ranked_10min.csv dataset with the information about player compositions and personal player information using Cassiopeia API**

# %%
# !pip install cassiopeia
# Out:
# Requirement already satisfied: cassiopeia in /usr/local/lib/python3.6/dist-packages (4.0.13)
# Requirement already satisfied: arrow in /usr/local/lib/python3.6/dist-packages (from cassiopeia) (0.15.8)
# Requirement already satisfied: datapipelines>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from cassiopeia) (1.0.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from cassiopeia) (2.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from cassiopeia) (7.0.0)
# Requirement already satisfied: merakicommons>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from cassiopeia) (1.0.9)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from arrow->cassiopeia) (2.8.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from datapipelines>=1.0.7->cassiopeia) (2.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->cassiopeia) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->cassiopeia) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->cassiopeia) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->cassiopeia) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->arrow->cassiopeia) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->datapipelines>=1.0.7->cassiopeia) (4.4.2)

# %%
from cassiopeia.core import Summoner, MatchHistory, Match
from cassiopeia import Champion, ChampionMastery
from cassiopeia import Queue, Patch
import pandas as pd
import random
from math import ceil,floor

import cassiopeia as cass

cass.set_riot_api_key("Your key")  # This overrides the value set in your configuration/settings.
cass.set_default_region("NA")

# %%
df = pd.read_csv('/content/drive/My Drive/LolAnalytics/high_diamond_ranked_10min.csv')

# %%
def getmatch(record):
  ID = int(record['gameId'])
  servers = [region.value for region in list((cass.Region))]
  for server in servers: # This is necessary because riot api wants us to specify region and our data doesnt include that
      try:
        match1 = cass.get_match(id = ID , region = server)
        match1.red_team.participants
      except Exception:
        pass
      else:
        print('match found')
        return match1

# %%
# def get_champion_compositions(match):
  
#   def turn_dict(list_of_tuples):
#     return {f'Summoner {i}': my_tuple for i, my_tuplee in enumerate(list_of_tuples)}
  
#   blue_team_composition = [(participant.role.value,participant.champion.id,participant.champion.name) for participant in list(match.blue_team.participants)]
#   red_team_composition = [(participant.role.value,participant.champion.id,participant.champion.name) for participant in list(match.red_team.participants)]
#   return turn_dict(blue_team_composition), turn_dict(red_team_composition)

# %%
def get_champion_compositions(match):

      blue_team_composition = {f'Blue_champ_{i+1}':participant.champion.name for i,participant in enumerate(list(match.blue_team.participants))}
      red_team_composition = {f'Red_champ_{i+1}':participant.champion.name for i,participant in enumerate(list(match.red_team.participants))}
      return blue_team_composition, red_team_composition

# %%
def get_lowest_team_account_level(match): # pretty good predictor of having a smurf in team if < 50-70
  
  lowest_lvl_blue = 500
  region1 = match.region
  
  for participant in match.blue_team.participants:
    
    player = Summoner(name=participant.summoner.name, region=region1)
    if isinstance(player, Summoner) == False:
      continue
    if player.level <= lowest_lvl_blue:
      
      lowest_lvl_blue = player.level
    

  lowest_lvl_red = 500
  
  for participant in match.red_team.participants:
    
    player = Summoner(name=participant.summoner.name, region=region1)
    if isinstance(player, Summoner) == False:
      continue
    if player.level <= lowest_lvl_red:
      
      lowest_lvl_red = player.level
    

  
  return {'lowest_lvl_red':lowest_lvl_red, 'lowest_lvl_blue':lowest_lvl_blue}

# %%
def get_average_team_maestry(match):  
  
  blue_team_sum = 0
  region1 = match.region
  
  for participant in match.blue_team.participants:
    
    player = Summoner(name=participant.summoner.name, region=region1)
    champ = Champion(name=participant.champion.name, id = participant.champion.id, region =  region1)
    cm = cass.get_champion_mastery(champion=champ, summoner=player, region =  region1)
    blue_team_sum += cm.points

  red_team_sum = 0
  
  for participant in match.red_team.participants:
    
    player = Summoner(name=participant.summoner.name, region=region1)
    champ = Champion(name=participant.champion.name, id = participant.champion.id, region = region1)
    cm = cass.get_champion_mastery(champion=champ, summoner=player, region =  region1)
    red_team_sum += cm.points
  
  return {'Blue_avg_mastery': ceil(blue_team_sum/5),'Red_avg_mastery':ceil(red_team_sum/5)}

# %%
def add_information_to_row(row,list_of_dicts):

  for dictionary in list_of_dicts:

    for item in dictionary.items():
      row[str(item[0])] = item[1]
  
  return row

# %%
def update_row(row):
  
  match = getmatch(row)                       # can optimize by changing the order of servers into EUW -> EUNE -> NA-> KOREA -> REST
  #a = get_average_team_maestry(match)         # sends 10 requests per iteration
  b = get_lowest_team_account_level(match)    # 10 requests per iteration
  c,d = get_champion_compositions(match)      # 1 request per iteration
  add_information_to_row(row,[b,c,d])
  return row

# %%
def update_dataframe(df):
  new_df = pd.DataFrame()
  
  for i in range(0,len(df)):
    row = df.iloc[i]
    try:
      update_row(row)
    except Exception:
      pass
    else:
      new_df = new_df.append(update_row(row),ignore_index = True)

    print(f'{i+1} of {len(df)} iterations complete')
  return new_df

# %% [markdown]
# Due to the riot API request limit of 50/min i can't update entire dataset with all the features i wanted, so i'll instead update a subset of the data, feed it to a model and use its output as a feature to a meta model. Also i didnt use team mastery as a feature because it roughly doubles the time for each iteration and it isnt really a good predictor of ones mastery over a champion(ironically).

# %%
sample = df.sample(200)
df_with_new_features = update_dataframe(sample)
# Out:
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4515839148
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4515839148
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4515839148
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/YTzZxQuSlcu6d13BB0maO-9wpzbaZSQCTZJJqOyniOBfzPA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/396CUX8OXY8YLs9c32bHZihteJZBKduZHAiW0-D9F67QSdI
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4515839148
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4515839148
# match found
# 1 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4527239272
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4527239272
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4527239272
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Ev1YAMtfb87vEVJHenwC2pK7hFUdeJ7u__Fp_M7LwnYGb2ZP
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/_Te2AkPqKfO5-u9CQ5cxAiFH1CUoSBRTS-kIjbBQiP4u64I
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/utRLLQiXZoUmNmJVLWLMRI41bwQ1Szoum495E0Q-XylcDpQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/kygvYiohmDitgEc7DtM2Y7IC7GWrvrMw02Q2m1Kb0B6ymuY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Mjd9j0lq-CVlcGfM8XJL3H3q27rO3lrLIkd7orhr1MVQMudE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/rP8ezZXK99t-YE4_yWrudaH4XPVSSS5Rr55qs4uySz-xn_M
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qsaebyqqWc27DsWrP4yi-gIv2euBVsx7B4byX662hcEHLKs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/H8od803jSU7vSPp2WyHPOydeAmrj6M0y-lDWwuPnbJ2vDAE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/-b6X7u3_9-UilpLfgLvs3J6AeRJMXN0K6tdA7B6pbBZHqO0
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4527239272
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4527239272
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/thuggeragain
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/SmileAtDeath
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Jawalehutt
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Riwanovic
# 2 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4495044073
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4495044073
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4495044073
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/wTrpKSR2C8Z6sZ7kLvjgtzHiH8IWGAl0dq4ki7UnAsV6_mc
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qeZ11M1DhMYIG4AMeqOL9G_y4y1cBpIc1Wrj15riarzCwmWb
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/axjVaYDeZc1xrPGgaeMV9EnFGAHx9yEDKmzpIPf4Q-ieQgY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/K-cCIMvxgE94ipDQsRcXbreevzENRUXd-aIdyT0d5s7GHOqb
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/DXwQVvZIMsa52uU6rOxvDfxmRqeSv1Y0NgdlVOB3bgvNU4g
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4495044073
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4495044073
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/ImBersie
# 3 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4526133153
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4526133153
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4526133153
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/DpS8BEzQUg7_2bYq89oM2MMOdTPf0yRn5rB5I15sr3iiIsM
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/OJq_A6Q2KDRDm1_1clHFM6yOrrjiHwI9voD0sVM2qJrPoUs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/pnlvpbLs5mhhhp-DpDSlne6pbq20NKAA4G9LbnsWtHitLWk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/a978S45v5B2lu3PWxCxa-IuC1b5LNxA_2QI8XdvXim4ehFQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/iRsgNJeMsPL_8YugI3vP3e0OFWDKLTGUNMmFcfxvQhTwrIY
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4526133153
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4526133153
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/funsoloqtimes
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DRJimsY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Iwwom
# 4 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4516105924
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4516105924
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4516105924
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/6U63g6t4kGzqa628UOGr2wIuHRnSSd7by8fRCpyW-Jn7rCXR
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/NaYJlLeWf73CXoDYBrVaXL3yD-I2mpAPq0ebhQIDZ33ZuWc
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/CmvN4a-9fzDsZeimytqVlefs2gCh-UiCzgWBxb3SrqwHqxs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/-ftdEuLzvl_y3bP_dQRPmt3JFva3K1i-z-OtqKmk5diMCV3h
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4516105924
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4516105924
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TOGCaesar
# 5 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4515542024
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4515542024
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4515542024
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/h5XUIR1KboacjuBOkKQLVZGHECZWoyAVN58cKkXjKSh7pPQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/gXzkRbUChiKaTOc2ktCjE6CxLZ30VUQL_gcMCUznd0DUQkY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/V1GOaSHPmFTQEYa4qbn6BMOsZvey17D8ngD2XwYSxh0PSGQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/WNnDa-Hb01emQ-BDkBVYu4Dx9McMHZtsr-5eNQl2RVViWrE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qLov47tzFtQA0Qn4EhLOdFrBRA6YXfokootDcE5lOQ3rgG2I
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/bVxw7jEr_E0sMRdHu90uuvts0La5sxXw-9PnduhHdp8Zpczm
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/AAQhXt3Y-h7XGT-4RoSV5E8yhfAjEUeIS1d-4JhVf6etrnc
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4515542024
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4515542024
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Jester1
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MSFVino
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/midgoesbzbzz
# 6 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4524259924
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4524259924
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4524259924
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/aO1GSRHpSvYSkWZVyt6fit4_pYSSWqeYVKtP93dWMR_sUD7S
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/IJ3L2B5VfuHn_yUDMgBLNCEIW2kQHyL2L-9AFtQ5bTI05zy5
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5ZjoLSERDVwNQi8KYijQgr9NIlBdxSOq1gGPJeMSrld2v-A
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/nqmmrhBQ285FiVWcNkH-qrz9tfLbvHGncEDXPcdNl4fzyRQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/BbadbZiL1FjLvpI5o6WorQyPgjHp6lT_Y_9CvvouajgGmIw
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4524259924
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4524259924
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/OeSHeste
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/NotKv0th3
# 7 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4520801995
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4520801995
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4520801995
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/YQp9xDHYQk18kcZrXC969LYw1sWG4h-smA_ugmBPosu3DZqf
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5uz0bcUZZ8eUpadShQxMkr0wlXFAtDNDOWoRQv-ww78Kpr8
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4520801995
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4520801995
# match found
# 8 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4510792748
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4510792748
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4510792748
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qFptfZiE0E2Y7uiQUfXhgtaeF0Ap8P2l7s3s-PMO_d7NcOFH
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Tp1SV1RsxZkpmyK-0INAOORenkPTtRIMBwdml9tdsZCSxdE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/k_KczQTO-AuAnGAqgQ1MfenIdpLglG-qUhm7SaWJ8dgaqIg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1m9yuQfbKRLeOBmaUlwMdkeEd-C1oMhGHGT71BxlQIGlxtI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/_UuupesrEs4aLAhW_R4DTWG8-3h51JUtq-rGwv263hR4MFY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/4btOBfjyeSNzvLcXOPTaaRlSPZpa9CfavGkTvRJqP8x9czU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/jNzCr2JWmHKjnaQXu1QPGegdtsV3zts9PsHI840XOaheuTw
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4510792748
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4510792748
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DouyuTV7779989
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/SimpDestroyerz
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MTWManki
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Hach\xce\xb9
# 9 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4517778477
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4517778477
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4517778477
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/g4M6P0u7wPbmi0QEVKwYgRtJe3vDht0gP1FsPbjIeIPsGAg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/i_HGxAuvPXxR9JrU_Rj7XnpI6z_i2anRbPZDsbvDfkI7Sv0
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5SqQIbKn4MduBceadg-kVC3hyozwIbGpNbCIGd6U333ypaQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/M_xpkG4FO2QYlCOE3EkTY3-8hDN-uMmolFOIg_E4p5rS9tE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Gl06qxULMIvMX-IU-9X9EXML6E95DtuchVlGI39vmLnjLm8e
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4517778477
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4517778477
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/AMlRAL
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MONSTERMURLOC
# 10 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4395598976
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4395598976
# match found
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4395598976
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4395598976
# match found
# 11 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4521352083
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4521352083
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4521352083
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/h081VV-Mgj1CvRCODMrj7dkADXMuhqD65jJp88WwJkeY9QU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/2_4SDJVaTMLpiaNkyaJEq90VCy3edNQqToWIEN1Q2pi7K3w
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Zus2D40RUJeUb00XMeK90p21yXywtVYZh42prFZkhsSX3rU1
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/2IbeeGcWWu6qtftMWq55K9Iz2rRqx6mExJDA60JngndJtak
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4521352083
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4521352083
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MTLKFabi0ov2
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/SeifurMD
# 12 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4518948833
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4518948833
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4518948833
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/bhxJmh5zmyZ1OycgbBMuY7l5qT2UboFafgVyqQGjG-mxLqU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/nirMUoOowOwJJMvXwG9fb9SVPbevkfWLruqXahsq2T6AFtY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/21__zGqxFATFszK7LY_IG_iYAk7CpGjsafNiIPdpLdFiXiE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/aLhkkg9hjoySWNEYyYiDLe1BoUAXCb-fQiaohyuDGHRUGo8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dCXJ1lf_tp9WPb6W_8Pw_JxoHEF-7UA6kQVz0-oAg-9uf1ua
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/L262cS8efqf3VYz1Ayj4taxi-fOw-CkeIu38Up3di6kijBuc
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4518948833
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4518948833
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/PROTEINSHAKEGUY
# 13 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4523591734
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4523591734
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4523591734
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/c8bgRrbbTlOaEmNLdRq7LPjRKZomnJvE9jkzMylCXr_D6aE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/pysl1HAn2ztSjsL0XiVvT8DCIS7_zpbtl5IQUyNf4fnu_Zk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/h4VCzSIntdT7Dx6zYdANdZJoD_k7SXjfZGrPGQKPDbg5W9hC
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/djlCk6tNYcL0piCAPxXYdJtXbkhhSXfCA5U5Wt5jKCZExyx7
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/9kYo4a6cusfM_BrjOT1TuUAoTe7rYsSC7VeTC1xhoyqkb_8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Bk_xv8L1WytQGt_BsHiZTvZIcXzkWxWvAc6japC2Q5099tw
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4523591734
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4523591734
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/ilbeback
# 14 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4514848234
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4514848234
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4514848234
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/unDnVvb7TDyXVqZCiBADRpNzUWHZIgCUDhe-Cxk2ybJd-_CG
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/V7tG9lXRFqnwKu9EDzicICxUh_5kf3EW04tXHNi4W2c8exA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qpgXqHx7oRrVTlRC8mUlcyPuuEROooQ8EGXK093dvV3o3DY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/bpNk4vTP6zklGzt3oQJDw0zh1MPkEujiOpfnYfmdtCL1OXc
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4514848234
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4514848234
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/EGNSLAYER
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DYNSquarepantsu
# 15 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4471506446
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4471506446
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4471506446
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/XXje6RFi4AQVeXiIJVKpPl3ZcsDh3e1-4sMSv5c55Lf_8Tk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dV6P4W9IcK16kVhf0E4fjJBIyS5hm6_OfdNgw9x2OBskHF2B
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ZBYRUMoFUIV5BnBVzdoeL7zjcZyN2U8vq_oEWDd8w0rPDOsz
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ZJgDx-GOorBnqiAkwHLux7QJhpBjy0gQzrzl9nF0Wxs7H3un
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4471506446
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4471506446
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/ProTestSkill
# 16 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4475174876
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4475174876
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4475174876
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/l_BJ4WgjePXIT88iR69totR8x9LLLziqrgoYcVGFMNnjwlM4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1J9BwiUjXw39yBMT2TmZBk6HHHLLdT1V5OYdLXqEebAvPpI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5YIb_oGi5SqyKWedqSG7zhHX5Ea5a1OCZinuFghaCFvRnCU
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4475174876
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4475174876
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Skeleton6
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/AGVegeta
# 17 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4488885595
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4488885595
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4488885595
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5yO--RiBySdVrkR4y-x80DKp8LKI1ptkFP7L9dB4FETGyUc
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/FjzYVbekF_Apdc0fE878AXxDgqHRgKa61YDcvhQB0t8gy10
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ru7aK2y_YhkjAbzg_rZ8vdnGzaLsXdir_U55_MTXnjB35CA
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4488885595
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4488885595
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DeCypher1
# 18 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4438793603
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4438793603
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4438793603
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/4U0ORpse-X5BXa_DFv95cg8sQK4H89j_-RTTgmhEpWpC
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/PaHe8YzlX0oUspKoXC4I4j0wjqdTcoNOoCq5IBA-McHOWkKg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qOdxKX40UFFtxBgwSr7EGwl4qkv-eCpyYJRSQG7Met8CwnU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ONoBJ9Upob2XVzKgvSK3keFZyfa9xtRd68pZ6HlgdVoPuj3d
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/QSykOdi4wiwx45vAcRCUlnLA_eZYRlDf8IQA0_GlyBlDc2RP
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1PuGafmbp23YQDMgVexaLXeoODee-N5LiTZ858Yj0QLmcdWi
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Io_DO5P0NLxu0-kxX2TGWSm9wWw3A6umXwm11dj0E7W-Txs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/3tv1L7h0a4h2oQ9dAjFBtQebeWKmuZ5-pd6Ux_PvA8LbQ7Q
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4438793603
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4438793603
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Nenji
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/andythebosss
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/ssimpli
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/D\xc3\xa0vy
# 19 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4489785292
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4489785292
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4489785292
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/kLUtX6oPx9C28gL7pG9yFx7IKcv-wrF3nDcj8pd8jqH8azw
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/0oDhCPD9j6kHl3tldwOgf0jNN_4rXcvw6SmabOGd7VTWf6I
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/rB--txJ8_4k02nb4_SXJEpIWiM__Jzz5-PO0IhTsBxBVDCk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/eGkPDgjiJTA4t17txD3aoMdN67jdC6F6h4vv8GptsK9mV5Q
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/MYEQIBW3KSjVgF-gDd2qREEzbxPwr1TzGo2ebs21r6K2Auk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/bx8_ZfI8ViyiKEXsoOCtVIRTcnbtP9jIzvXl_4ogdKY0A-pe
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4489785292
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4489785292
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/AeQRazergy
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/FYNWestlander
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/4891256219786
# 20 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4497870077
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4497870077
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4497870077
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/CG_bPzJRfGWnScKYEJYGKxMunpwcgyUlR6mD7mY_GpImrj8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/WuLK_u9nyKrITOsGZS0kQ_XoWZZeZHS532uZQV0yIIC9D_8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/fO-TqHLGsKEgc61Fk1nA2IvSMxqXkHJ2QEAB6KjKw4FmBkY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Fci5sIqoIq4IEP738bKDewek3PdIYwZuXzm9MHcUzxDe-3c
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/lCr67uTnhHPlLMcx-fGjtDU-SYT_XDv3HgjGXzYZuw2ogcQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/SXz0VM8owLcK-LNJF0ptrwQE6TlEhS2awIURgoVAoKdV
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4497870077
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4497870077
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/kemva
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/PizzaPeppe
# 21 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4509444763
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4509444763
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4509444763
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Qu-wR2HS_oYXgV0RuJREYp4XBod1HwRBrxuPakUORJvVwXo
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/JaWY1gblCbZz5Iaa51xC6f_SlIJfD5ePPLKYQ3FoqUh9XtU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/GWxgpPArbvzpI7mAROk6xjM0ptkOM-HsTWc1gHB1_p2d
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/nvV1oitgwa45QcV0UE_mFIAA0DHGkWie_tMIlHPTtw5iveo
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/KR02Nz0r6Zv-VC8JI1d3dK8dgwF1T7HdH8W285oZSNKfh4E
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/yJ40V3eiTLYroHgCaw_zvu3S5SVYkhAMMV43wYMzHm5Eflg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/aedrKLc7gGl-Shwpl4aqLa3rav2n6Bl15TBTquCFmcvCxJE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/r53RH_bHcHEoYW3T3S_n-QQZRJwGAECJ57AH24f_CGjktTM
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4509444763
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4509444763
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/For\xc3\xaatd\xc3\xadff\xc3\xa9rence
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/SoleilSouriant
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Lysberg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/LKBSleeping
# 22 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4442215686
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4442215686
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4442215686
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/XeyxFwImBPFJulsqi25ZQwIcwvO_kFobqb3nocRBT-G9aX8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/O8AoEStvcH0yqR0Li5oUEqxmzZ4-t1NCpmnCYyS_pXJGTGo
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5gWGEpq3VncRVfaiKLVHS2wSZJOqurpFKb2xs82mWN7CtOY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/kjYZhO-81aFggZspOsdIG6_ngMsi_6r4SkUk9Giw40-Zygk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/25L5wrvESdaXqtEx2699mpIG3D67qvV6Z6LSGSneY9bEJFg9
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/c7sFPjJTzzBf8whTyQ_bTw0d0ZDfcIe-1y0vPtDiy0q-5n0
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4442215686
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4442215686
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/S\xc5\x82IER
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/papijorx
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/PyosikClidNoltey
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/erdt
# 23 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4526299418
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4526299418
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4526299418
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/DAGY3AUzNwNEKTwiPUcn6_3RPyGK5fgFWFj8X9L55IbrA8o
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/z5OQ37jvepriBPtcCVMpkcbzKG7osJPjKxTaTepu3zURTpE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Du0-5CzMz_M7tOsQt7XnBc-rwkjPvZEX1OSpkny3bTqe36Qw
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/esybE6kqY9umnlQdIFHold5e04GVwU6yKQhpSSkAfpifFCg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/tLCrXdeaqK-DkvjaA2ua4E_XEhITPoaMHVM0ANkpaZN4AQw
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/amaYxbuqXW7Tlat2Du4QpPri7A9AjPOFMoGxa7zjtS_Z7F0
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/TMtcGvyVkr4tZ_QI064O_k7hLCx2BTY_nfFsEJuLIhLH-E8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/O9sB_7Mhx6GNJkTtR8MaQCLvlEZTTczw1vcgKEcJy9sFDwo
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4526299418
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4526299418
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/75251139
# 24 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4296354535
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4296354535
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4296354535
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/krdLS4q50W5R2mIf9jvZ50dQUAS2sheI2zTwwKa5aMmDvOo5
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ZtvVNA50mi-XD5zHgrO4E_-SQA_lJPURWlZI6n-EXNwmiLI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ajRiPsljN3iemOnksHoPNyA2reZ9fHwkroy1unTykHhqFUk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Fv4jbjEFv7EvRrzv4FrrfQPGf6OMlJo7L5kXCDqflN38wbZ1
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/7jaERbK7bPVgi7vVl1lPKUV4DvVPQLs92igIGu8vv5FaMmNA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/AItV8l2FjxPJZ9A_xKjVi72kyqIz7ZkMT46tPSh2jYD53wRN
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/QnnxFOn7fAiM2rbX-4yhaev3Ry1pN5tSyR76PErKLy5GAX4
# Making call: https://ddragon.leagueoflegends.com/cdn/9.23.1/data/en_GB/championFull.json
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4296354535
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4296354535
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/YNWMELLYY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/lllIllIlllIlllI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/M\xce\xb1M\xce\xb1n
# 25 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4450553888
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4450553888
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4450553888
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/FRCqVM2TBZw8DESlt4F9vVXncO1GGS_dpeX6doVZ2PscIUI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ESdgt862qbSukDXpl4_NuFPv7Oq2HGQwJ2G2bcYVZqo5nAs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/gqNh2ensfYhmWGKZxcV84SmRfxosj3I_5ExAHX0NQ_auecE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ajAnSZaeBLEPv5Og-KVPKx_7-eiHN56D3a0X1BzqQaHYw_Y
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/d4lOd0aiF6cC9A6gdK6zbs2nPrEI0016p2BDSjiiwoqkaNG2
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/zR6qvqMsvlPAL2C2RLUtLzhO_ckqMafI2s0uE3v2BorCZqU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/YlBaCWAFBdE5mawmF1jEeZUUiACOqXTE0kffQqS9TW5B
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4450553888
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4450553888
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/RobinAndRaphBFF
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/NGRINHEAD
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/LegendaryAlan
# 26 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4500687748
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4500687748
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4500687748
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/YSLU9CF-Jo_rRh29fYVW4LuldjBqijjJkcoFD0voB9sHmhcZ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/7MTshU2YAVxdz-rDur4gPmXy2LS0GOeFZy-jMAJAlCD3v1I
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/eGfdIBw1vo0jC6jte8isGbygn1__G03mgyrCAsTcshf1Iz4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/afn3iGULymrX7Gpi2LI4XioQ3J6Z1Mku3yNEGJY9GuD4HsA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/UMH2-deRINldoO6qMmElbFYsGE9-7k2jeyxU_EAHQqByygQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1gypegC_KOeGxaL9_GWXdM12cqCfqCwiLcd8aPkbivSSDoM
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/lBcBBicPTAGSIinv6pw440JFmoLTle7geAzGC0OVTnkAa4c
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4500687748
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4500687748
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/pure\xce\xbdessel
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/T1Sotsy
# 27 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519607934
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519607934
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4519607934
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/PpW2AcRYuXmCO9_KGVa3zu2gNt75Bo9pGIu7mAtd4tx0ccg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/wuqYkv7uq9iHjmDjI5647RMJzSNJO9siuNHT-s0nI1nCEvU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/nShZzSTe27NpAu4l7GRqJg2HdCpQbli5TYpH-86eYQNjuUn6
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/od7eaF7aKDMwGXL4SsPdvJySNSvygeX3PVGl4fOKiyqDMjY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/6ELdv57HiXaxirxhj4kVn85_UvolyejIbzVgH9WTy4snhxDv
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1yQwGJ_M6Lmjv-nWzJeadvjd_tQ0Q9UQBgtg7HznPGqkGWRE
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519607934
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519607934
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/PURUSUURUTORA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Pukistyle6666
# 28 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4474939096
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4474939096
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4474939096
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/-QlCsxt3-S4SaS2S-eO7qEZi4lb4tfja3QHH57k8zQ_7STjX
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/jNl6Lfy1LYyaPDPOCKh_0zfPNCZIv3ixP1qPYe-4mqFJgZk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/s_MHlJ93Hsh2NPHAYQCyUKyYcxvm-hpJyGB2EHR034_u4FA5
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/D2LDumuA80xwtkkLmFFxqjd9q_j3IcNuIAWlc2ULnKdmfCY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/_Qt8qs4bUn0x5H-AiCCLrt_zWVts2gGwyW_anG7fXYZSGW5S
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/RpYtkKQ_jitctYgv_wKO_pFaNyvwweTcMczeU5XA7cN3UE4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/bEC2uz_jt4ETGxJGDT7CIB7DiV-y-jpzKyh5wrVXfzF1Teo
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dgCe74NYiVfcm8unOHC4Zz9YrZ7SSqbv8Zxp2EOYaQu475FN
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4474939096
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4474939096
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/HadesLFT
# 29 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4523981551
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4523981551
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4523981551
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/BAQlJ1hu180Gu09iAx7IemW22M2TOSo9DZE5pUQFiv7rMX4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/_XwDA7x7u6eYFcWSQIuyIuEovk8YblJAspSO7ViMGIrqono
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qYYWulyTFg4-cC1-6yqhcrjMBIzacCNkKBkaQxAJ97_EYe4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/AcmJAzh57wMlQGkAtbgYb32Kbth25f9DdVK-gUlm7eOdoI8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/0RhivTfXMosPJqRvvnLm9yRui8ssg7Ys21KwOboRg_hUt-A
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/U9Kr-cLD7xVH7Rp0u6mJKMDO7QVOqYB1UZwyu4iCVFx6ebEA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/uBsjItKHHadI1XNYNg15784_J8JAuYZc1NFpT1QeQ8JWzuQH
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/374fJakBlHSGfAq_NHOo4pT8_miUrarfpIpxId13R9L9ByI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/C5EfNEzHjlXcu4mFfmeRbL5D6SaCFlBciDogDroLymh4W2Q
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/RejB2IPHjsiKOmbblYuZngEbDuz4fN2LqOPzz2dm1vPH7T2j
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4523981551
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4523981551
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/ItalianHero93
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Wapzy
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/\xc3\x87OMARKAAN
# 30 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4447488924
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4447488924
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4447488924
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Zxkqf7rKeT8sEQCAJiOgVv-Dqqecc0p_bhRCzwXe8PQETU4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/VpZv4kHxdWd-H5GHPkcXXTP1BOH7NvOK9YcuW7HKCE4SdtU
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/yGTx67g4gBK_jVnTQYEWFdRuTQGxr7EFrbKSoOiu5-nEFeE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/xOvqceo-UV8Mgu-i7PAD_dIZmI6pfmo_LtKm3MVPxsxFoto
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/4vd3GlYdg-z0jxyhN1bjMn-D8300Y0UVbEj6GMxH3YYtOfwZ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dKh83CA8S6jS1qczdg6cKqeNr6NkWN71YJPaSnko3wFOyU4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1X5tXHH-r0AcchHrw3pL7hrsUxeGjymH7z34QJiQuJT72Wg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/0nNMAw_HS-xQPbYpWqeKmhGgJrYnTJhvcdJx3pQCvHeRddw
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/AeA22nyV7lxlKxxl4-kZRC0PI3EDWJVyM2JIT99BA0wLPDE
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4447488924
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4447488924
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/KaynFlip
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/lll\xc5\xb8\xc4\x85l\xc3\xb8\xc5\x9blll
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Scenario7
# 31 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4473949665
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4473949665
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4473949665
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/gtydRJ2LdTJgqerk8SJFTBQHMbQsIfc7OvtGmR7RGkhN54sf
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/8fyNI95Yha2czUEYtVN3Apv1ZLVubZ5QCKY_BQ34ALw_r-Q
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/anAiIBOMkicgFIf5WXC-vEhpvYCTB540iQX61esHIBva1j1p
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4473949665
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4473949665
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/WilIyDias
# 32 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4517631475
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4517631475
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4517631475
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/LWFHj62HzRnmzrpZyUWpgp6z2YDTYiNVyyaWOOqe7R4F3Fg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/D9FN0uvwX6NGCGFwOEkSVtrTCdebdo-JAqUzvTCxME1KdxA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/QABV7vXgUoj2JQ2AzDC0xqZN9QtmdFM61RldrQ2aRIvPcJc
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/3PflmFz7FoDrpZadviin407yiv3NqetGcwf6cPtPen5XZCg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/pdyDcY-uRG9wxJWlMusdELNc_Ox76DJS4lDLHOa1dkmiOO06
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4517631475
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4517631475
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/MeSAnbu
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TanjiroK\xce\xb1m\xce\xb1do
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/garyfromthegulag
# 33 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4481806461
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4481806461
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4481806461
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/HbK842XoZUJb7_pzyv5t8E0jASBKW338rjcVRxFiKwfTX5s
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/g1JRhjW0WN6M3xo0GJXPoBJUNcqBRW9eHLge3jXQKZfoEp0D
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/DPRyKXhUnCcr5DwwUUxJC_0YG0dAKgw8t61Ya6P_1zAq9Ko
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/PzMfWQB_jTUmYQRWkKXwR2rWpGfzQgT-Ui6O0yRgMo8mmgI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/nrdVdGhoH2oVKt1t4GPJbgIKxBrZ1L9AAcpd7EoGn81-oKQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dEO4F38CGXGQ55yd4Jpuaji6UTcoHVT7N0qs7Yx8O5BnO0cv
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4481806461
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4481806461
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/nishimuraya
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/TheCrossman
# 34 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519431177
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519431177
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4519431177
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/crf9DOn0MLZW07TWEhAmyulCyG0rCxhqVEmn7LLP0AugdyA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/tf69ouUK7-sqmMukLs84XsZ2-_EIskWvLTa6DF-6Q2efx3s
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/OXPh62BYm0xGQS_TWyYza22XK4i3q4Wuyp_Yr2zfvjQgaDEE
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519431177
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519431177
# match found
# 35 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4525827145
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4525827145
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4525827145
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/3X0DhlxV66U7ogZIRAkb2-LYCBL5IN4y-qEsJFHxu1ayNJRQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/5eFTdAAhL-pM7LISPmIATDLujrBb3mkRXs003GS2pjCQVJTb
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/81SSFBSAXC1dnqbAdZAiXtuFHEQDFyhoTIJt6kmeehy6WMY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/rWZt-f6LIuasuHOAesjRkBZ3AaTVzKlaItlRpz_k63r3U7M
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4525827145
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4525827145
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/L\xc3\xafnkz
# 36 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4478776750
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4478776750
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4478776750
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/FVtf1uQSboT-cSoE_WaOl7JbJm8-wmZiXyLydxmN3khWRQed
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Gp66HeoniVcxriPk8ry_6R7VX8NB12GSv1uWQHU5-9bC8ec
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/CeEQGpZkhjtphGQ96Ry9YopTxOLH_SK5UgtJB_whfAw8Je8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/lIldqW5f9goe7lHOd4PCbG-ese5GE-DQTP7LghKiAMcxN_fZ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/GJNxC9w9sM5UC9lWi5QFoferrGYQv8EGpofPB_rq9KNjGFU
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4478776750
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4478776750
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/S\xce\x99CKOMODE
# 37 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4430925118
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4430925118
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4430925118
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/TJ590j_ZU0Wt4_oQAMqF1WsdTqX_FwndvYPdc5jEjGsJQQE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/V225c5m8zfIkA8crr3O8xXxIP6vpIg0YpOaM5J2GbcdGFX-g
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/U3M4ZaFhIfAN-ZLziTR67VnDjgyA4W6H7oXDm3x8C8lIvEY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/fBgs9oTXBQ5bYjDuR521CXAOsMSVVileLUyFv69pA9Whyhxy
# ...
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519057052
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4519057052
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/OiEzv_LvIAIVce23VmuW3WfhuZhFr9yDEzXp88ZfPvIAzag
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/PNGHV9AbLplKnMjcD9QL-Eu-82MRDZWim3pE7YfBsH6duyU
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519057052
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519057052
# match found
# 186 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4478393634
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4478393634
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4478393634
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/hcLqhv7oIWDa6IjMM0I0OyjQRnluJodvJtz0TtWEwkmw8Lk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/VMyq4pwzFzPA_j37i4TwEzPX1XPiwSBHLZLZc2Rb8mfnl0w
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/mCiAXF2oyZ3B_19XqSmDtwHV-8nmPgQXEKh4ASwqloivgHs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dkgoc8eqB5Pth7roUUSi1lPT2Q6BBNrq3b_58lBNfb9Vmg8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/7Zyfne4la_0OD3LRswZkyWN8Wvw5B4hgytQLo7nGo-qkp40
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4478393634
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4478393634
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Shafu
# 187 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4518159499
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4518159499
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4518159499
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/uOyiYyjWODpZdkm_8atOItcmIGCbuGatFWgaP42yVPtOnZlr
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/xMC7TVJoS1Sj06JoofDu8-Rr-INZFK9Ags6lyiuttL4L5J4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/_tKfzmBY0y-stW8xXD7lBrS4agx6tgev5d9z3weGwC-ei_o
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/gj6rK6vRArYZXjT4EAXDLF1UP_XYWvkstce84BQ6PWhtuDk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/c4-Y_hVk0AV-msZ_wWF4c56ItZBANrLJ9LbqfiRTMbTM-mY
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4518159499
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4518159499
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/SAMGotzy
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/AccioTetas
# 188 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4462027689
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4462027689
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4462027689
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Lk5CP5NlpKbpM6TvRlhJWKS2uUK3xhW-ponUj2qh_USW8l4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/IuYnC-zx2KGmKIjRB3BN-3orZ_-VVXteBFNFxJQerOy228g
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/peVriMEYaMIeN3eYHDxffUGihWKFMLVaKUiRo6DelRm_31g
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/hO9RAQyMTJ3NkZHoLhqz9XLEtrJsrhQAEZxS020scItlYR4
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/VgoesIZd_KTmVlKLyt6aVpRAsAzTH6VDCLprSu69kdtmwJo
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4462027689
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4462027689
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Lightcat
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/ATRBardo
# 189 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4527328545
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4527328545
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4527328545
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/_OyugNGlyyrFSFHRYeydIev97Xp0ur8llAjZvXXcuoq3QLJo
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ATA3FI5QmL7ehtRi6WsE6Jtdfhe2wzWD09MAEsBxOOrog4Y
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4527328545
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4527328545
# match found
# 190 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4474804095
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4474804095
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4474804095
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/3yuc_gq2ySQdMNqB6UGnJdC7MMSf8nPnZz5SE4IUt901vjJK
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/yfiXWXzU24S6hYnwMO0c7E010G772RcK6f30XQ46nn5xFFI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/NcpuPL5uJ2g6SZJY7bldZAnMcvSIK45Am1e11QcBoRMfvBY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/o5fZ2p41DohosslRt1zhxIkeZ1RVx60CKUe_G0i3TMBg-hQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/hpFx-eKXJZV0_kI5h7RuyUJCRWqIYDhLP63rc9MlxSmCeFQ
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4474804095
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4474804095
# match found
# 191 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4523556317
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4523556317
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4523556317
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/slJtMUw9Lkf4siYcqQ0miRtD3Pcfb-rkCV-c8yjosnGNcxk-
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/sXIeq9y1f4jAWBuv_6ERepv24owLnfytxEgCS7XBiPdCN0y9
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4523556317
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4523556317
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/BeHumanPLZ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/xflaidyv2
# 192 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519991680
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519991680
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4519991680
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/z0Oefy3yR6dofpFSbt8Xl03QoHx16_DqAWJx6gxLAPf5Vkqd
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/vf34DGDYPyVrO6E8TbRt0kVoNdZGkIUXf7CVzr3PcUREzOk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/w0QGkjIDURmcfHPbEyARNH2iyQeoPN0e3G040czu6FXcc6c
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/dO8DPS6x7cuJjS3gkXuI5GdToS4acAp10zlQDtjDoT0QlIE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Urd_b7yjn6R5xriEDYmweRNxZAem4igSDRklzv5aGbaBiTE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/A7IREdAglbxWhKWtPwzbJwIRgodcOcU3CVsEWtfuITGeaKI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/iSG7RVIbZE6j3AY1ltN6vtiQ2bkbzRPaaMK-_ZNHCR9y-Lw
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/vBJMOitxvauDcdA-junldeVwI_NnxiPb-AuCknRKJVufCnA
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4519991680
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4519991680
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DFXHumnam
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/GreenButton
# 193 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4501386832
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4501386832
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4501386832
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/xAmycFOZX9FrlT-QuYfTKAU_BFIpjYN4DV97RFjB1-dCjeg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1v8MBGujzam3p8jPZOBEVQHt5f2u8qwkt95Pq0bldER6jNQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ZQ2smJRUhqTxijVFOrQlvKwnV_0DhASOU4RE70OZOTWf0r7E
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/540l604FYqtFIRdze_YbdsxEo3r8yNi3rDgrnyUAlvGIyKO0
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/7ex3EAIDfrN0eyDKYG3x2Mkl4lYWdQtqR4fJQetyNabYYEY
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4501386832
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4501386832
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/xmar
# 194 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4509325423
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4509325423
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4509325423
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/P-TzHt5hnoNIkSrgUZb_2lWJnr-5lTzf_l5Wd-A0qMWgO8U
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4509325423
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4509325423
# match found
# 195 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4452228031
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4452228031
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4452228031
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/qdW3WAkzSo_tf8iw0qsUymx0kU62fI9lNPGqSpBTR0hFM8A
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/wjET4wgu7qoAvONb2bTTRRJLQjFd0YvD_gHsTXsDrv-6dfk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/b3YkUkrPNk0CGbrzXUgr_MJLmsuJ4_EbEpn0yqAfWipv0F58
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/zDZaXRyoeEhFhTm0q_itR66bjbY4YDT4rPKmDQa8OyrKjBQN
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/CpvI0gutHBWSZeu70evgGOTta8Y1sLNBQTSIsP7w9Qz3aFI
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/G8VUfgJ0CRvjRrR3MUMUe9gnIouPvq-n-scDcTs1AFKt9Hg
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/FmTQZtx3VH1No4A5H2dOjQ6gQtBQ4woN0EgSUCtz0w0JDZM
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4452228031
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4452228031
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/EternityXanadu
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Neuranius
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/FortitudeCPM
# 196 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4520341861
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4520341861
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4520341861
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/HGl6OalWeCPdYkhPNcHSgGxNDQkyQeYHayuvpQhVmy_DYFE
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/IjXJI6GqPMwwbhdICL9iRxGiJQCe4gKanVkwgqjiDAe36Yk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/6yp72nJA8JoHOiBbypkhT3eVnQ7hLfBW7AP8mRjrpUeCqC7o
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/SMW69sjvUluMRnXr-GRyIQFgD2XtmN6rYRVLQCAceHzGnCQQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/0U_NYDVd4eyLGzzwfDmCeej2PBL5miITFlwrerHd1KMLb2M
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/HMznWQuYkgIkuoQSssyA55XfVBn3kltXy3ic06LKiLW72lk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/K8eU5byvIn24R2R_aEXgXVLG4wCySyT7Swvu9KL8Oje_XDA
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/Zo5_iTIFoneIQZinQ9YFSSjGeBaWPuAGjBfvJ9SlFcl5bRFG
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4520341861
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4520341861
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/Antares2
# 197 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4513811621
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4513811621
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4513811621
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/cIeGGlYCOPgnpEYD0kTWsAqT10cUF4dKxIZz2EaGu9EHF9U
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/-Wa6NMTSj-gFo6QqtnDXcHaQywy3ikqhJHbLyBBMSTUKMns
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/l4n34Lg7H-JGqx0cU7OVtEcEfr-dasTSf2-m1j99Znf4l6g
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/SjYqQF7OJSGKAJyZPJD56smgKHi_e_2sN5RasmR9-EjVtgk
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/EdZPvtVuS5oWIdhNnuebuaERSHd9KOaUS_29S3q_huJxdS4s
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/3Qh54Y0BoBcH5YDFry0gHYfYRnYKkkAzQpXtVjCJqDHsprI
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4513811621
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4513811621
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/LaurelCastillo
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/DYoiceInMaYead
# 198 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4481379221
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4481379221
# match found
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4481379221
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4481379221
# match found
# 199 of 200 iterations complete
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4502587670
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4502587670
# Making call: https://euw1.api.riotgames.com/lol/match/v4/matches/4502587670
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/fLaBL9_BW0aoR_3k-pJlx7jy-Uk1lm5YUGf9JK0hw3z_LCs
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/1mbXGS3GMR7OPrJ0bX9lNU8yIbXIonvK6DERKc7HmIbNvsQ
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/pWS868iNAho8MdMxA5tDGxmymhAuJvvN8eWvauW8ANvsz5AT
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/NDzNAIHi_6UbXfLUZlRai8G-WWKfJM5nHkpEwooudxrEZbCY
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/I7AiLQBOTEjH9BNxcR-YOJCt0A6wlQzVVsNaW2f3z454si8
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/ksGpp7GnRTrqRe76sidviF1wNUwaosXlfe5icCTXbdzYJ1Y
# Making call: https://br1.api.riotgames.com/lol/match/v4/matches/4502587670
# Making call: https://eun1.api.riotgames.com/lol/match/v4/matches/4502587670
# match found
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/VNRArentz
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/JANNANUCLEEAARR
# Making call: https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/AL\xc3\x89BIBOU
# 200 of 200 iterations complete

# %%
df_with_new_features.to_csv('/content/drive/My Drive/LolAnalytics/high_diamond_ranked_10min_with_added_features.csv')
